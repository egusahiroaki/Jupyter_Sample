# %%
import pandas as pd
#trip_df1 = pd.read_csv("babs_open_data_year_1/201402_babs_open_data/201402_trip_data.csv", sep=",")

trip_df3 = pd.read_csv("babs_open_data_year_3/201608_trip_data.csv", sep=",")

# %%
trip_df3["Duration"] /= 60

# %%
from datetime import datetime as dt


trip_df3["Start Date"] =  trip_df3["Start Date"].apply(lambda d: dt.strptime(str(d), "%m/%d/%Y %H:%M"))

# %%
trip_df3["End Date"] =  trip_df3["End Date"].apply(lambda d: dt.strptime(str(d), "%m/%d/%Y %H:%M"))

# %%
top_count_trip = trip_df3[(trip_df3["Start Station"] == "Townsend at 7th") & (trip_df3["End Station"] == "San Francisco Caltrain 2 (330 Townsend)")]

# %%
top_count_trip_sub = top_count_trip[top_count_trip["Subscriber Type"] == "Subscriber"]

# %%
# %matplotlib inline
import seaborn as sns
start_datetime = top_count_trip_sub.groupby(["Trip ID"])["Start Date"].first().reset_index()
df_start_date = pd.DataFrame(start_datetime)
sns.distplot(df_start_date["Start Date"].dt.hour, kde=False, rug=False, axlabel="Trip Start Time Count by hour (Subscriber)",hist_kws={"range": [1,24]}, bins=24)

# %%
end_datetime = top_count_trip_sub.groupby(["Trip ID"])["End Date"].first().reset_index()
df_start_date = pd.DataFrame(end_datetime)
sns.distplot(df_start_date["End Date"].dt.hour, kde=False, rug=False, axlabel="Trip End Time Count by hour (Subscriber)",hist_kws={"range": [1,24]}, bins=24)

# %%
top_reverse_count_trip = trip_df3[(trip_df3["Start Station"] == "San Francisco Caltrain 2 (330 Townsend)") & (trip_df3["End Station"] == "Townsend at 7th")]

# %%
top_reverse_count_trip_sub = top_reverse_count_trip[top_reverse_count_trip["Subscriber Type"] == "Subscriber"]

# %%
start_datetime = top_reverse_count_trip_sub.groupby(["Trip ID"])["Start Date"].first().reset_index()
df_start_date = pd.DataFrame(start_datetime)
sns.distplot(df_start_date["Start Date"].dt.hour, kde=False, rug=False, axlabel="Trip Start Time Count by hour (Subscriber)",hist_kws={"range": [1,24]}, bins=24)

# %%
status_df3 = pd.read_csv("babs_open_data_year_3/201608_status_data.csv", sep=",")

# %%
# 69.0	San Francisco Caltrain 2 (330 Townsend)
top_trip_dock_start_place_df = status_df3[status_df3["station_id"] == 69]

# %%
top_trip_dock_start_place_df["time"] =  top_trip_dock_start_place_df["time"].apply(lambda d: dt.strptime(str(d), "%m/%d/%Y %H:%M:%S"))
# Out:
# /Users/egusahiroaki/.pyenv/versions/3.5.2/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
top_trip_dock_start_place_df.head(2)
# Out:
#           station_id  bikes_available  docks_available                time
# 28900495          69               15                8 2015-09-01 00:00:02
# 28900496          69               15                8 2015-09-01 00:01:02

# %%
#morning_df = top_trip_dock_start_place_df[(top_trip_dock_start_place_df["time"].dt.hour >= 8) & (top_trip_dock_start_place_df["time"].dt.hour < 10)]

# %%
morning_df.shape
# Out:
# (42269, 4)

# %%
# month_df =  top_trip_dock_start_place_df[top_trip_dock_start_place_df["time"].dt.month == 4]
# month_df.groupby([month_df["time"].dt.hour])["bikes_available"].mean()
# Out:
# time
# 0     17.120468
# 1     17.208357
# 2     17.235031
# 3     17.253417
# 4     17.232475
# 5     17.287843
# 6     17.559976
# 7     16.515116
# 8     12.325350
# 9      8.139535
# 10     6.080399
# 11     5.845486
# 12     5.551546
# 13     5.541311
# 14     5.589977
# 15     4.980660
# 16     5.663456
# 17    11.292211
# 18    15.009034
# 19    15.099271
# 20    15.378499
# 21    16.288602
# 22    16.865513
# 23    17.006723
# Name: bikes_available, dtype: float64

# %%
sf_bikes = top_trip_dock_start_place_df.groupby([top_trip_dock_start_place_df["time"].dt.hour])["bikes_available"].mean()
sf_bikes.plot()

# %%
sf_bikes = top_trip_dock_start_place_df.groupby([top_trip_dock_start_place_df["time"].dt.hour])["docks_available"].mean()
sf_bikes.plot()

# %%
# 65.0	Townsend at 7th
top_trip_dock_end_place_df = status_df3[status_df3["station_id"] == 65]
top_trip_dock_end_place_df["time"] =  top_trip_dock_end_place_df["time"].apply(lambda d: dt.strptime(str(d), "%m/%d/%Y %H:%M:%S"))
# Out:
# /Users/egusahiroaki/.pyenv/versions/3.5.2/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
te_bikes = top_trip_dock_end_place_df.groupby([top_trip_dock_end_place_df["time"].dt.hour])["bikes_available"].mean()

# %%
te_bikes.plot()

# %%
te_bikes = top_trip_dock_end_place_df.groupby([top_trip_dock_end_place_df["time"].dt.hour])["docks_available"].mean()
te_bikes.plot()

# %%
top_count_trip_cus = top_count_trip[top_count_trip["Subscriber Type"] == "Customer"]

# %%
# カスタマーの移動開始時刻
start_datetime = top_count_trip_cus.groupby(["Trip ID"])["Start Date"].first().reset_index()
df_start_date = pd.DataFrame(start_datetime)
sns.distplot(df_start_date["Start Date"].dt.hour, kde=False, rug=False, axlabel="Trip Start Time Count by hour (Customer)",hist_kws={"range": [1,24]}, bins=24)

# %%
top_reverse_count_trip_cus = top_reverse_count_trip[top_reverse_count_trip["Subscriber Type"] == "Customer"]

# %%
# カスタマーの移動開始時刻
start_datetime = top_reverse_count_trip_cus.groupby(["Trip ID"])["Start Date"].first().reset_index()
df_start_date = pd.DataFrame(start_datetime)
sns.distplot(df_start_date["Start Date"].dt.hour, kde=False, rug=False, axlabel="Trip Start Time Count by hour (Customer)",hist_kws={"range": [1,24]}, bins=24)

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# 円グラフを描画
label = ["Customer", "Subscriber"]

x = np.array([len(top_reverse_count_trip_cus.index),len(top_reverse_count_trip_sub.index)])
colors = ["lightpink", "yellow", "gold", "slateblue", "lightcoral"]
plt.pie(x, labels=label,counterclock=False, autopct='%1.1f%%',startangle=90, colors=colors,wedgeprops={'linewidth': 3, 'edgecolor':"white"})
plt.axis('equal')
# Out:
# (-1.0029540065312357,
#  1.0069258961133571,
#  -1.0052631274184798,
#  1.0000000181428539)

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# 円グラフを描画
label = ["Customer", "Subscriber"]

x = np.array([len(top_count_trip_cus.index),len(top_count_trip_sub.index)])
colors = ["lightpink", "yellow", "gold", "slateblue", "lightcoral"]
plt.pie(x, labels=label,counterclock=False, autopct='%1.1f%%',startangle=90, colors=colors,wedgeprops={'linewidth': 3, 'edgecolor':"white"})
plt.axis('equal')
# Out:
# (-1.0038608993989306, 1.007934500328771, -1.0065068078383346, 1.0)
